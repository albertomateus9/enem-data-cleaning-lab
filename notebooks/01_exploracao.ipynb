# %% [markdown]
# # Laboratorio De Limpeza De Dados Do ENEM
#
# Limpeza de dados estilo ENEM com pandas, tratamento de nulos, padronizacao e exportacao segura.
#
# Este notebook registra uma exploração leve sobre amostras seguras e reprodutíveis.

# %%
from pathlib import Path
ROOT = Path.cwd().parents[0]
print("Notebook didático pronto para execução local.")
